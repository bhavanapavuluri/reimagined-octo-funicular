# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanapavuluri/reimagined-octo-funicular/blob/master/code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
    print(uploaded[filename])
# Out:
#      <input type="file" id="files-bcc2717e-58fd-40a5-b39d-1d00d40b42c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcc2717e-58fd-40a5-b39d-1d00d40b42c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testimg1.jpg to testimg1 (1).jpg
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xfe\x00;CREATOR: gd-jpeg v1.0 (using IJG JPEG v62), quality = 75\n\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x03\xeb\x03\xff\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf7\xca(\xa2\xa8\x02\x8a(\xa0\x02\x8a)\xa5\xb0O\x19\xc7&\x80\x1dH\xc7\x18\x03\xa9\xa6\xf2X\xe0\xe0\x8f\xcb\x14\x80\x9d\xd9\' q\x9a\x00\x0e\x0eC3{\x9cqK\xce@\'\xe6\x1c\x83\xeb@\xdc\x17n\xdc\xfb\xf6\xa4\xdb\xb8\x81\x9f\xba1\x9fz@8\x00\xdc\x8e\x1b\xa5(\x18\xe4\x9c\x93\xde\x800?\xad-0\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\nB\xa0\xfd}ii\t\xc0&\x80\x01\x9cs\x8c\xd2\xd3\x0f\x00\x12I\xa4\x1f\xec\xe4\x1fL\xd0\x03\xc8$pq@\x00\x0c\n\x14\xe4R\xd0\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E4\xb1\x07\x00d\xf5\xebM\xfb\xcd\x90H\xe0\x11@\x0fc\x81\xc7S\xc0\xa6\x1cr\tc\xeb\x8e\x94\x99!\xb99\ny&\x9c7.@\x19\xe7 \xe6\x80\x13\x8c\x05\'\xddM/\r\xc1\x18aH\x14\x1c/]\xa3\x93\xefO\x03\x1e\xfe\xe6\x80\x00\xb89\'&\x96\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x01\n\x83\xec}h\x19\xc7=iO\x02\x98~\xe8$\x93\x9e\xd4\x00\xfaC\xc8\xe0\xe2\x98\x0f\xf7A\x07\xd0\x1az\x9c\x8e}h\x00\x00(\xc0\xa5\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00*7\xf9\xb3\x80I\x1d\xc5;q=\x14\x91\xebL\xc8\xdb\xb5\x8b)\x1c\xd0\x01\x81\x8d\xeaN?\x95/\xde\xce1\x93\xf7\x81\xa4\x04.\x19I*N\x08\xa7*\x83\x9c\xaf\x1d\xb3@\r\x07p(O\xd1\xbdi\xe8r\x80\x81\x8aR\x01\x18 b\x80A\xe9@\x0bE\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01ES\x8fT\xd3\xe6\xd4f\xd3\xa3\xbd\xb7{\xd8pd\xb7YT\xc8\x99\x19\x19^\xbd\r\\\xa0\x02\x8a(\xa0\x02\x8a\x8ei\xe2\xb6\x85\xe6\x9eT\x8a$\x19gv\n\xaa=I5\x82\x9e>\xf0\x8c\x97"\xdd<M\xa4\x99I\xc6>\xd6\x9c\x9f\xaeqH\x0e\x8a\x8aj:H\x8a\xe8\xc1\x95\x86AS\x90E:\x98\x05!\xe4\x10:\xe2\x90\x93\x9d\xab\xd7\xf9R\x85\n(\x01\xa4\x82\x07\\\xfd)\x17\x00\xe4\xe7\xf5\xa9(\xa0\x04_\xbbKXz\x97\x8c<7\xa3_\x0b-G[\xb0\xb5\xb9\xe0\x98\xa6\xb8Ua\x9e\x99\x1d\xbf\x1a ...

# %%
import cv2
import numpy as np

# Path of working folder on Disk
def get_string(img_path_in_colab):
    
    # Read image with opencv
    img = cv2.imread(img_path_in_colab)

    # adjust contrast and brightness
    contrast_img = cv2.addWeighted(img, 2.5, np.zeros(img.shape, img.dtype), 0, 20)

    # Convert to gray
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # blur
    img_blur = cv2.GaussianBlur(img,(5,5),0)

    #edges
    edge_img = cv2.Canny(img,100,200)
    
    #padding
    top, bottom, left, right = [150]*4
    img_with_border = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_REPLICATE)

    #  Apply threshold to get image with only black and white
    filtered = cv2.adaptiveThreshold(img.astype(np.uint8), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 199, 5)
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(filtered, cv2.MORPH_OPEN, kernel)
    closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
    or_image = cv2.bitwise_or(img, closing)

     # Write image after removing noise
    cv2.imwrite("removed_noise.png", img)

    # Write the image after apply opencv to do some ...
    cv2.imwrite(img_path_in_colab, img)

    # Recognize text with tesseract for python
    extractedInformation = pytesseract.image_to_string(Image.open (img_path_in_colab))

    # Remove template file
    return extractedInformation

print (get_string(filename))
# Out:
# ABCDEFGHIJKLA
# NOPQRSTUVWXYZ
# abcdetohijk bm
# nopgrstuwxyz
# 1234564890
# -——IfOO090C5
#
# KPO == reo @F#&HZ
# PP rot 8 K/ IVE SOT]
